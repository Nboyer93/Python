# %% [markdown]
# # Final Project-Stock Tracker

# %% [markdown]
# ## Objective:

# %% [markdown]
# To visualize and analyze stock price data over a certain time period. The user will input the stock ticker into the function stock_data along with the start time (how far back you want to look at the stock.) From here, we calculate the minimum and maximum closing prices of the stock over those dates. These values are used to calculate the resistance and support levels. We then count how many times the stock price reached resistance or support over the time period. Whichever is greater tells us if the stock is trending upwards or downwards and whether we should buy or sell.

# %% [markdown]
# ## Actions:

# %% [markdown]
# Enter the desired stock ticker as a string and the start date in form (year,month,day) in the stock_data function stored in variable stock

# %%
from my_module.functions import *

# %%
stock=stock_data('AAPL',start(2019,12,1))

# %%
buy_or_sell(stock)

graph(stock)
# Out:
# Buy
